# %%
import os
import sys
# Get the root directory (parent of 'notebooks/')
root_dir = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(root_dir)

# %%
from model import train
from model import tests

# %%
tests.test_forward_passes()
# Out:
# CodeSimLinearClassifierCross output shape: torch.Size([1, 1])
# CodeSimLinearClassifierSBert output shape: torch.Size([1, 1])
# CodeSimContrastiveEncoder output shape: torch.Size([1, 768])

# %%
config = train.configs.CodeSimContrastiveClassifierConfig()
config.epochs = 1
config.num_batches = 5
config.bs = 1
config.num_negatives = 2
config.use_info_nce_inspired_loss = True

train.finetune_model_contrastive(config=config)

# %%
config = train.configs.CodeSimClassifierConfig()
config.epochs = 2
config.bs = 1
config.num_rows = 5
config.finetuning_strategy = "binary_cls_sbert"

train.finetune_model(config=config)

# %%
config = train.configs.CodeSimClassifierConfig()
config.epochs = 2
config.bs = 1
config.num_rows = 5
config.finetuning_strategy = "binary_cls_simpl"

train.finetune_model(config=config)

# %%
from peft import LoraConfig

config = train.configs.CodeSimContrastiveClassifierConfig()
config.pretrained_model_name = "Qwen/Qwen3-Embedding-0.6B"
config.epochs = 1
config.num_batches = 5
config.bs = 1
config.num_negatives = 2
config.use_info_nce_inspired_loss = True
config.lora_config = LoraConfig(
    r=8,
    lora_alpha=16,
    lora_dropout=0.05,
    bias="none",
    target_modules=["q_proj","k_proj","v_proj"],
    task_type="FEATURE_EXTRACTION",
)
config.pooling_strat = train.code_sim_models.qwen3_pooling_strat

train.finetune_model_contrastive(config=config)
# Out:
# Pretrained checkpoint name: Qwen/Qwen3-Embedding-0.6B
# Initializing encoder model.
# Wrapping model with lora config for parameter efficient finetuning.
# Creating CodeNet dataset. Data type: triplet
#
#         problem_id submission_id    status                    code
# count      128400        128400    128400                  128400
# unique        428        128400         2                  125189
# top        p03711    s543499340  Accepted  print(int(input())**2)
# freq          300             1     85600                      22
#
# Splitting dataset...
# Train size: 102720, Valid size: 12840, Test size: 12840
# EPOCH 1/1
#   0%|          | 0/5 [00:00<?, ?it/s]
# /home/peter/repos/CodeSim/.venv/lib/python3.11/site-packages/torch/amp/autocast_mode.py:266: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# Iteration 1/5 complete. Loss: 0.3377622961997986
# Iteration 2/5 complete. Loss: 0.6519207954406738
# ...
