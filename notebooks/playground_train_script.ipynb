# %%
import os
import sys
# Get the root directory (parent of 'notebooks/')
root_dir = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(root_dir)

# %%
from model import train
from model import tests

# %%
tests.test_forward_passes()

# %%
config = train.configs.CodeSimContrastiveClassifierConfig()
config.finetuning_strategy = "info_nce_loss"
config.epochs = 1
config.num_batches = 5
config.bs = 1
config.num_negatives = 1

train.finetune_model_contrastive(config=config, use_poj=True)
