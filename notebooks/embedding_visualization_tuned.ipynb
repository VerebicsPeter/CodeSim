# %%
import os
import sys
# Get the root directory (parent of 'notebooks/')
root_dir = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(root_dir)

# %%
from model import train

# %%
import torch
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import transformers
from sklearn.manifold import TSNE

# %%
CHECKPOINT = "huggingface/CodeBERTa-small-v1"

# %%
bert = transformers.AutoModel.from_pretrained(CHECKPOINT)
bert_tokenizer = transformers.AutoTokenizer.from_pretrained(CHECKPOINT)

# %%
path = "/home/peter/Downloads/codesim_models/CLS_pooling_new_dataset_10_epochs_infoNCE/model.pt"
model = train.CodeSimSBertTripletENC(bert)
model.load_state_dict(torch.load(path, map_location=torch.device('cpu')))
model.eval()
# Out:
# CodeSimSBertTripletENC(
#   (bert): RobertaModel(
#     (embeddings): RobertaEmbeddings(
#       (word_embeddings): Embedding(52000, 768, padding_idx=1)
#       (position_embeddings): Embedding(514, 768, padding_idx=1)
#       (token_type_embeddings): Embedding(1, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): RobertaEncoder(
#       (layer): ModuleList(
#         (0-5): 6 x RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): RobertaPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (drop): Dropout(p=0.2, inplace=False)
# )

# %%
data = pd.read_csv("/home/peter/repos/CodeSim/dataset/output_large.csv")
data
# Out:
#        problem_id submission_id        status  \
# 0          p03711    s543499340      Accepted
# 1          p03711    s354804624      Accepted
# 2          p03711    s945585026      Accepted
# 3          p03711    s767362367      Accepted
# 4          p03711    s594100945      Accepted
# ...           ...           ...           ...
# 128395     p03261    s583865019  Wrong Answer
# 128396     p03261    s627756319  Wrong Answer
# 128397     p03261    s206613132  Wrong Answer
# 128398     p03261    s522444501  Wrong Answer
# 128399     p03261    s789042486  Wrong Answer
#
#                                                      code
# 0       x, y = map(int, input().split())\na = [1,3,5,7...
# 1       x, y = map(int, input().split())\na = [2]\nb =...
# 2       l1 = [1,3,5,7,8,10,12]\nl2 = [4,6,9,11]\nl3 = ...
# 3       x,y = map(int, input().split())\nA = [1,3,5,7,...
# 4       x, y = map(int, input().split())\n\nlist_1 = [...
# ...                                                   ...
# 128395  N = int(input())\nW = [input() for i in range(...
# 128396  N = int(input())\nW = []\nfor i in range(N):\n...
# 128397  n=int(input())\na=[]\nfor n in range(n):\n  a....
# 128398  N = int(input())\nW = [input() for i in range(...
# 128399  n = int(input())\nlst = []\nflag = True\ntmp =...
#
# [128400 rows x 4 columns]

# %%
train_df, valid_df, test_df = train.code_sim_datasets.split_df(data)
test_df
# Out:
#       problem_id submission_id        status  \
# 0         p02957    s799365635      Accepted
# 1         p03796    s192773874  Wrong Answer
# 2         p03309    s527090882      Accepted
# 3         p03860    s573700277      Accepted
# 4         p03761    s650372064      Accepted
# ...          ...           ...           ...
# 12835     p03836    s335858471      Accepted
# 12836     p02900    s911537671      Accepted
# 12837     p02917    s792747082      Accepted
# 12838     p02608    s047282668      Accepted
# 12839     p03127    s454946406  Wrong Answer
#
#                                                     code
# 0      A,B = map(int,input().split())\nN = A+B\n\nif ...
# 1      INF = 10**7 + 7\n\nN = int(input())\npower = 1...
# 2      #coding: utf-8\nimport math\nimport heapq\nimp...
# 3      a = input().split()\ns = a[1][0]\nans = 'A' + ...
# 4      n = int(input())\ns = [input() for _ in range(...
# ...                                                  ...
# 12835  sx,sy,tx,ty = map(int,input().split())\nprint(...
# 12836  import fractions\na,b=map(int,input().split())...
# 12837  n = int(input())\nb = [int(_) for _ in input()...
# 12838  import collections\n\nn = int(input())\nans_li...
# 12839  n = int(input())\na = sorted(map(int, input()....
#
# [12840 rows x 4 columns]

# %%
test_df.value_counts("status")
# Out:
# status
# Accepted        9416
# Wrong Answer    3424
# Name: count, dtype: int64

# %%
test_df.value_counts("problem_id")
# Out:
# problem_id
# p02546    30
# p03371    30
# p03359    30
# p03352    30
# p03351    30
#           ..
# p02802    30
# p02801    30
# p02797    30
# p02796    30
# p04045    30
# Name: count, Length: 428, dtype: int64

# %%
def get_samples_to_plot(df: pd.DataFrame, num_samples=20, num_problems=13):

    samples = {}
    statuses = {}
    for i, (group, group_df) in enumerate(df.groupby("problem_id")):
        print(f"Group: {group}")
        sample = group_df.sample(num_samples, random_state=42)
        samples [group] = sample["code"]  .to_list()
        statuses[group] = sample["status"].to_list()
        if i > num_problems: break
    
    tokenize = \
        lambda code : bert_tokenizer(code, padding=True, truncation=True, return_tensors="pt")
    
    samples_enc = {}

    for problem in samples:
        for code in samples[problem]:
            samples_enc[problem] = tokenize(samples[problem])
    
    samples_emb = {}

    for problem in samples_enc:
        with torch.no_grad():  embeddings = model(samples_enc[problem])
        samples_emb[problem] = embeddings
    
    embs = []
    lbls = []
    stss = []  # statuses

    for label, tensors in samples_emb.items():
        for i, tensor in enumerate(tensors):
            embs.append(tensor.detach().cpu().numpy())
            lbls.append(label)
            stss.append(statuses[label][i])
    
    return embs, lbls, stss

# %%
embs_1, lbls_1, stss_1 = get_samples_to_plot(test_df)
tsne_1 = TSNE(n_components=2, random_state=42)
reduced_embeddings_1 = tsne_1.fit_transform(np.stack(embs_1))
# Out:
# Group: p02546
# Group: p02547
# Group: p02548
# Group: p02552
# Group: p02553
# Group: p02554
# Group: p02555
# Group: p02556
# Group: p02570
# Group: p02571
# Group: p02572
# Group: p02576
# Group: p02577
# Group: p02578
# Group: p02582

# %%
embs_2, lbls_2, stss_2 = get_samples_to_plot(train_df)
tsne_2 = TSNE(n_components=2, random_state=42)
reduced_embeddings_2 = tsne_2.fit_transform(np.stack(embs_2))
# Out:
# Group: p02546
# Group: p02547
# Group: p02548
# Group: p02552
# Group: p02553
# Group: p02554
# Group: p02555
# Group: p02556
# Group: p02570
# Group: p02571
# Group: p02572
# Group: p02576
# Group: p02577
# Group: p02578
# Group: p02582

# %%
def plot_reduced_embeddings(reduced_embeddings, problems, statuses, title):
    data = pd.DataFrame(reduced_embeddings, columns=['x','y'])
    data['problems'] = problems
    data["statuses"] = statuses
    markers = {"Wrong Answer": 'X', "Accepted": 'o'}

    plt.figure(figsize=(10, 8))
    sns.scatterplot(
        data=data,
        x='x', y='y',
        hue='problems',
        style='statuses',
        markers=markers,
        s=100,
        edgecolor='black',
        legend='full'
    )
    plt.title(title)
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.tight_layout()
    plt.show()

# %%
plot_reduced_embeddings(reduced_embeddings_1, lbls_1, stss_1,
                        "TSNE projections of BERT embeddings (from test set)")

# %%
plot_reduced_embeddings(reduced_embeddings_2, lbls_2, stss_2,
                        "TSNE projections of BERT embeddings (from train set)")
