# %%
# TODO: maybe precalculate the augmentations and include them with the same label

# %%
import os
import pandas as pd
import random
# functions for reading data from codenet:
import codenet_reader

# %%
# Functions for processing solutions of a problem


def label(pid: str, row) -> str:
    status = 1 if row['status'] == 'Accepted' else 0
    return f'{pid}-{status}'


def process_pid(pid: str, srcs: list[str], lbls: list[str]):
    MIN_SOLUTIONS = 5
    MAX_SOLUTIONS = 250
    
    num_python_solutions = len(codenet_reader.python_solutions(pid))
    if num_python_solutions < 5:
        return
    
    df = codenet_reader.init_metadata_df(pid)
    if df is None:
        return
    
    if df.shape[0] < MIN_SOLUTIONS:
        return
    
    if df.shape[0] > MAX_SOLUTIONS:
        df = df.sample(MAX_SOLUTIONS, ignore_index=True)
    
    print(f'{pid}','-'*50)
    print(f' sampled {df.shape[0]} code snippets')
    
    df['src'] = df.apply(lambda row: codenet_reader.read_solution_file(pid, row['submission_id']), axis=1)
    df['lbl'] = df.apply(lambda row: label(pid, row), axis=1)
    
    new_srcs = df['src']
    new_lbls = df['lbl']
    
    srcs.extend(new_srcs.to_list())
    lbls.extend(new_lbls.to_list())
    
    return new_srcs, new_lbls


def test():
    return process_pid('p03200', [], [])
    #return process_pid('p01701', [], [])

# %%
test()
# Out:
# p03200 --------------------------------------------------
#  sampled 250 code snippets
# (0      S=list(input())\nans=0\nbl=0\nfor s in S:\n  i...
#  1      S = list(input())\n\nblacks = []\nfor i in ran...
#  2      import sys\na = input()\nS = [s for s in a]\n#...
#  3      s = input()\nans = 0\n\ndef reverse(s,i):\n  i...
#  4      import re\nimport sys\nimport math\nimport ite...
#                               ...
#  245    s = input()\ncnt_b = 0\nans = 0\nfor c in s:\n...
#  246    S = input()[::-1]\nw = 0\nans = 0\nfor e in S:...
#  247    S = list(input())\n\ncnt = 0\nfor i in range(l...
#  248    def myAnswer(S:list) -> int:\n   N = len(S)\n ...
#  249    import math\nimport fractions\nimport bisect\n...
#  Name: src, Length: 250, dtype: object,
#  0      p03200-1
#  1      p03200-1
#  2      p03200-0
#  3      p03200-0
#  4      p03200-1
#           ...
#  245    p03200-1
#  246    p03200-1
#  247    p03200-0
#  248    p03200-0
#  249    p03200-1
#  Name: lbl, Length: 250, dtype: object)

# %%
# Reading data

SAMPLE_SIZE = 500

_pids = os.listdir(codenet_reader.DATA_PATH)
_pids = random.sample(_pids, k=min(SAMPLE_SIZE, len(_pids)))

srcs = []
lbls = []

print('Starting...')
print(f'Processing {len(_pids)} problems.')

for _pid in _pids:
    process_pid(_pid, srcs, lbls)

n_srcs = len(srcs)
n_lbls = len(lbls)
assert n_srcs == n_lbls

accepted_count = sum(1 for lbl in lbls if lbl[-1]=='1')
rejected_count = n_srcs - accepted_count

print('Data gathered...')
print(f'{len(srcs)} code snippets:')
print(f' {accepted_count} accepted')
print(f' {rejected_count} rejected')

output_ls = list(zip(srcs, lbls))
output_df = pd.DataFrame(output_ls, columns=['source', 'label'])

print('DONE')
# Out:
# Starting...
# Processing 500 problems.
# p02394 --------------------------------------------------
#  sampled 250 code snippets
# p03244 --------------------------------------------------
#  sampled 250 code snippets
# p02340 --------------------------------------------------
#  sampled 7 code snippets
# p02890 --------------------------------------------------
#  sampled 97 code snippets
# p03037 --------------------------------------------------
#  sampled 250 code snippets
# p03504 --------------------------------------------------
#  sampled 250 code snippets
# p02439 --------------------------------------------------
#  sampled 27 code snippets
# p03005 --------------------------------------------------
#  sampled 250 code snippets
# p04000 --------------------------------------------------
#  sampled 250 code snippets
# p02952 --------------------------------------------------
#  sampled 250 code snippets
# p03210 --------------------------------------------------
#  sampled 250 code snippets
# p02893 --------------------------------------------------
#  sampled 21 code snippets
# p03126 --------------------------------------------------
#  sampled 250 code snippets
# p04026 --------------------------------------------------
#  sampled 215 code snippets
# p02832 --------------------------------------------------
#  sampled 250 code snippets
# p00710 --------------------------------------------------
#  sampled 14 code snippets
# p02945 --------------------------------------------------
#  sampled 250 code snippets
# p04001 --------------------------------------------------
#  sampled 250 code snippets
# p03213 --------------------------------------------------
#  sampled 250 code snippets
# p03455 --------------------------------------------------
#  sampled 250 code snippets
# p03767 --------------------------------------------------
#  sampled 250 code snippets
# p02745 --------------------------------------------------
#  sampled 250 code snippets
# p00074 --------------------------------------------------
#  sampled 5 code snippets
# p03179 --------------------------------------------------
#  sampled 100 code snippets
# p02734 --------------------------------------------------
#  sampled 250 code snippets
# p02345 --------------------------------------------------
#  sampled 68 code snippets
# p02433 --------------------------------------------------
#  sampled 23 code snippets
# p02653 --------------------------------------------------
#  sampled 18 code snippets
# p00444 --------------------------------------------------
#  sampled 158 code snippets
# p02938 --------------------------------------------------
#  sampled 23 code snippets
# p02449 --------------------------------------------------
#  sampled 11 code snippets
# p00376 --------------------------------------------------
#  sampled 161 code snippets
# p03549 --------------------------------------------------
#  sampled 250 code snippets
# p02903 --------------------------------------------------
#  sampled 250 code snippets
# p04012 --------------------------------------------------
#  sampled 250 code snippets
# p02726 --------------------------------------------------
#  sampled 250 code snippets
# p02823 --------------------------------------------------
#  sampled 250 code snippets
# p03575 --------------------------------------------------
#  sampled 250 code snippets
# p03848 --------------------------------------------------
#  sampled 250 code snippets
# p03267 --------------------------------------------------
#  sampled 192 code snippets
# p02466 --------------------------------------------------
#  sampled 9 code snippets
# p00251 --------------------------------------------------
#  sampled 155 code snippets
# p03187 --------------------------------------------------
#  sampled 14 code snippets
# p03594 --------------------------------------------------
#  sampled 16 code snippets
# p02339 --------------------------------------------------
#  sampled 11 code snippets
# p03229 --------------------------------------------------
#  sampled 250 code snippets
# p03374 --------------------------------------------------
#  sampled 50 code snippets
# p02878 --------------------------------------------------
#  sampled 6 code snippets
# p02821 --------------------------------------------------
#  sampled 250 code snippets
# p02619 --------------------------------------------------
#  sampled 250 code snippets
# p02723 --------------------------------------------------
#  sampled 250 code snippets
# p02846 --------------------------------------------------
#  sampled 250 code snippets
# p03557 --------------------------------------------------
#  sampled 250 code snippets
# p03607 --------------------------------------------------
#  sampled 250 code snippets
# p03675 --------------------------------------------------
#  sampled 47 code snippets
# p03671 --------------------------------------------------
#  sampled 250 code snippets
# p02709 --------------------------------------------------
#  sampled 250 code snippets
# p03690 --------------------------------------------------
#  sampled 16 code snippets
# p02588 --------------------------------------------------
#  sampled 250 code snippets
# p03759 --------------------------------------------------
#  sampled 250 code snippets
# p03590 --------------------------------------------------
#  sampled 25 code snippets
# p02594 --------------------------------------------------
#  sampled 250 code snippets
# p03306 --------------------------------------------------
#  sampled 91 code snippets
# p03460 --------------------------------------------------
#  sampled 31 code snippets
# p03083 --------------------------------------------------
#  sampled 34 code snippets
# p00401 --------------------------------------------------
#  sampled 24 code snippets
# p02632 --------------------------------------------------
#  sampled 250 code snippets
# p03547 --------------------------------------------------
#  sampled 250 code snippets
# p03458 --------------------------------------------------
#  sampled 250 code snippets
# p03141 --------------------------------------------------
#  sampled 250 code snippets
# p03523 --------------------------------------------------
#  sampled 250 code snippets
# p02934 --------------------------------------------------
#  sampled 250 code snippets
# p02888 --------------------------------------------------
#  sampled 250 code snippets
# p03503 --------------------------------------------------
#  sampled 250 code snippets
# p02472 --------------------------------------------------
#  sampled 43 code snippets
# p02633 --------------------------------------------------
#  sampled 250 code snippets
# p00836 --------------------------------------------------
#  sampled 7 code snippets
# p03293 --------------------------------------------------
#  sampled 250 code snippets
# p03175 --------------------------------------------------
#  sampled 250 code snippets
# p03105 --------------------------------------------------
#  sampled 250 code snippets
# p02460 --------------------------------------------------
#  sampled 13 code snippets
# p03249 --------------------------------------------------
#  sampled 6 code snippets
# p03944 --------------------------------------------------
#  sampled 250 code snippets
# p03347 --------------------------------------------------
#  sampled 250 code snippets
# p00047 --------------------------------------------------
#  sampled 6 code snippets
# p03588 --------------------------------------------------
#  sampled 250 code snippets
# p02861 --------------------------------------------------
#  sampled 250 code snippets
# p02402 --------------------------------------------------
#  sampled 250 code snippets
# p03841 --------------------------------------------------
#  sampled 112 code snippets
# p03864 --------------------------------------------------
#  sampled 97 code snippets
# p03260 --------------------------------------------------
#  sampled 250 code snippets
# p02775 --------------------------------------------------
#  sampled 250 code snippets
# p03693 --------------------------------------------------
#  sampled 250 code snippets
# p00015 --------------------------------------------------
#  sampled 9 code snippets
# p03072 --------------------------------------------------
#  sampled 250 code snippets
# p02792 --------------------------------------------------
#  sampled 250 code snippets
# p03127 --------------------------------------------------
#  sampled 250 code snippets
# p02233 --------------------------------------------------
#  sampled 250 code snippets
# p03104 --------------------------------------------------
#  sampled 250 code snippets
# p02730 --------------------------------------------------
#  sampled 250 code snippets
# p02777 --------------------------------------------------
#  sampled 250 code snippets
# p02421 --------------------------------------------------
#  sampled 250 code snippets
# p02583 --------------------------------------------------
#  sampled 250 code snippets
# p02235 --------------------------------------------------
#  sampled 67 code snippets
# p00433 --------------------------------------------------
#  sampled 8 code snippets
# p03154 --------------------------------------------------
#  sampled 27 code snippets
# p02556 --------------------------------------------------
#  sampled 250 code snippets
# p04017 --------------------------------------------------
#  sampled 112 code snippets
# p03731 --------------------------------------------------
#  sampled 250 code snippets
# p02677 --------------------------------------------------
#  sampled 250 code snippets
# p02305 --------------------------------------------------
#  sampled 7 code snippets
# p03096 --------------------------------------------------
#  sampled 250 code snippets
# p03490 --------------------------------------------------
#  sampled 64 code snippets
# p03069 --------------------------------------------------
#  sampled 250 code snippets
# p03407 --------------------------------------------------
#  sampled 250 code snippets
# p02540 --------------------------------------------------
#  sampled 250 code snippets
# p03986 --------------------------------------------------
#  sampled 250 code snippets
# p03680 --------------------------------------------------
#  sampled 250 code snippets
# p03262 --------------------------------------------------
#  sampled 250 code snippets
# p03524 --------------------------------------------------
#  sampled 250 code snippets
# p03769 --------------------------------------------------
#  sampled 27 code snippets
# p03827 --------------------------------------------------
#  sampled 250 code snippets
# p03799 --------------------------------------------------
#  sampled 250 code snippets
# p03858 --------------------------------------------------
#  sampled 9 code snippets
# p03039 --------------------------------------------------
#  sampled 250 code snippets
# p02269 --------------------------------------------------
#  sampled 141 code snippets
# p03204 --------------------------------------------------
#  sampled 6 code snippets
# p03062 --------------------------------------------------
#  sampled 250 code snippets
# p03048 --------------------------------------------------
#  sampled 250 code snippets
# p02963 --------------------------------------------------
#  sampled 250 code snippets
# p03215 --------------------------------------------------
#  sampled 250 code snippets
# p02647 --------------------------------------------------
#  sampled 250 code snippets
# p03411 --------------------------------------------------
#  sampled 145 code snippets
# p01267 --------------------------------------------------
#  sampled 5 code snippets
# p02666 --------------------------------------------------
#  sampled 131 code snippets
# p03550 --------------------------------------------------
#  sampled 249 code snippets
# p03821 --------------------------------------------------
#  sampled 250 code snippets
# p03381 --------------------------------------------------
#  sampled 64 code snippets
# p02603 --------------------------------------------------
#  sampled 250 code snippets
# p03685 --------------------------------------------------
#  sampled 80 code snippets
# p03723 --------------------------------------------------
#  sampled 250 code snippets
# p03356 --------------------------------------------------
#  sampled 250 code snippets
# p03844 --------------------------------------------------
#  sampled 250 code snippets
# p03636 --------------------------------------------------
#  sampled 250 code snippets
# p02960 --------------------------------------------------
#  sampled 250 code snippets
# p02658 --------------------------------------------------
#  sampled 250 code snippets
# p03200 --------------------------------------------------
#  sampled 250 code snippets
# p02268 --------------------------------------------------
#  sampled 250 code snippets
# p03044 --------------------------------------------------
#  sampled 250 code snippets
# p03093 --------------------------------------------------
#  sampled 5 code snippets
# p02438 --------------------------------------------------
#  sampled 13 code snippets
# p02667 --------------------------------------------------
#  sampled 167 code snippets
# p03617 --------------------------------------------------
#  sampled 250 code snippets
# p02432 --------------------------------------------------
#  sampled 44 code snippets
# p03976 --------------------------------------------------
#  sampled 18 code snippets
# p02367 --------------------------------------------------
#  sampled 14 code snippets
# p03735 --------------------------------------------------
#  sampled 31 code snippets
# p03867 --------------------------------------------------
#  sampled 10 code snippets
# p02598 --------------------------------------------------
#  sampled 250 code snippets
# p02346 --------------------------------------------------
#  sampled 39 code snippets
# p03630 --------------------------------------------------
#  sampled 6 code snippets
# p04029 --------------------------------------------------
#  sampled 250 code snippets
# p03148 --------------------------------------------------
#  sampled 250 code snippets
# p03149 --------------------------------------------------
#  sampled 250 code snippets
# p03638 --------------------------------------------------
#  sampled 250 code snippets
# p04014 --------------------------------------------------
#  sampled 228 code snippets
# p02562 --------------------------------------------------
#  sampled 95 code snippets
# p02544 --------------------------------------------------
#  sampled 7 code snippets
# p03910 --------------------------------------------------
#  sampled 250 code snippets
# p02961 --------------------------------------------------
#  sampled 148 code snippets
# p03423 --------------------------------------------------
#  sampled 250 code snippets
# p02725 --------------------------------------------------
#  sampled 250 code snippets
# p04007 --------------------------------------------------
#  sampled 26 code snippets
# p02241 --------------------------------------------------
#  sampled 49 code snippets
# p03752 --------------------------------------------------
#  sampled 250 code snippets
# p00051 --------------------------------------------------
#  sampled 5 code snippets
# p00175 --------------------------------------------------
#  sampled 5 code snippets
# p03220 --------------------------------------------------
#  sampled 250 code snippets
# p02399 --------------------------------------------------
#  sampled 250 code snippets
# p03287 --------------------------------------------------
#  sampled 250 code snippets
# p03178 --------------------------------------------------
#  sampled 250 code snippets
# p00553 --------------------------------------------------
#  sampled 16 code snippets
# p03792 --------------------------------------------------
#  sampled 31 code snippets
# p02879 --------------------------------------------------
#  sampled 250 code snippets
# p02686 --------------------------------------------------
#  sampled 250 code snippets
# p02822 --------------------------------------------------
#  sampled 250 code snippets
# p02288 --------------------------------------------------
#  sampled 50 code snippets
# p03140 --------------------------------------------------
#  sampled 240 code snippets
# p02550 --------------------------------------------------
#  sampled 250 code snippets
# p02950 --------------------------------------------------
#  sampled 84 code snippets
# p02613 --------------------------------------------------
#  sampled 250 code snippets
# p02923 --------------------------------------------------
#  sampled 250 code snippets
# p02897 --------------------------------------------------
#  sampled 250 code snippets
# p03477 --------------------------------------------------
#  sampled 250 code snippets
# p03856 --------------------------------------------------
#  sampled 62 code snippets
# p03662 --------------------------------------------------
#  sampled 48 code snippets
# p03271 --------------------------------------------------
#  sampled 11 code snippets
# p02651 --------------------------------------------------
#  sampled 250 code snippets
# p03409 --------------------------------------------------
#  sampled 250 code snippets
# p03852 --------------------------------------------------
#  sampled 250 code snippets
# p02803 --------------------------------------------------
#  sampled 250 code snippets
# Data gathered...
# 34806 code snippets:
#  21002 accepted
#  13804 rejected
# DONE

# %%
output_df
# Out:
#                                                   source     label
# 0      W,H,x,y,r = map(int,input().split())\nFlag=Tru...  p02394-1
# 1      W,H,x,y,r=map(int,input().split())\nif x>=0 an...  p02394-1
# 2      W, H, x, y, r = map(int, input().split())\n\ni...  p02394-1
# 3      w, h, x, y, r = map(int, input().split())\nres...  p02394-1
# 4      W,H,x,y,r=list(map(int,input().split()))\nif x...  p02394-1
# ...                                                  ...       ...
# 34801  from collections import deque\nH, W = map(int,...  p02803-0
# 34802  from collections import deque\n \nh, w = map(i...  p02803-1
# 34803  from collections import deque\n''' \nINF = flo...  p02803-0
# 34804  H, W = map(int, input().split())\nS = []\nfor ...  p02803-1
# 34805  import collections as cl\ndef check(y,x):\n   ...  p02803-0
#
# [34806 rows x 2 columns]

# %%
# Exporting
EXPORTED_FILE_NAME = 'output_single.csv'
output_df.to_csv(EXPORTED_FILE_NAME)
