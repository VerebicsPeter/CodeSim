# %%
# TODO: maybe precalculate the augmentations and include them with the same label

# %%
import os
import pandas as pd
import random
# functions for reading data from codenet:
import codenet_reader

# %%
# Functions for processing solutions of a problem


def label(pid: str, row) -> str:
    status = 1 if row['status'] == 'Accepted' else 0
    return f'{pid}-{status}'


def process_pid(pid: str, srcs: list[str], lbls: list[str]):
    MIN_SOLUTIONS = 5
    MAX_SOLUTIONS = 250
    
    num_python_solutions = len(codenet_reader.python_solutions(pid))
    if num_python_solutions < 5:
        return
    
    df = codenet_reader.init_metadata_df(pid)
    df = df[df['status'].isin({'Accepted', 'Wrong Answer'})]
    
    if df is None:
        return
    
    if df.shape[0] < MIN_SOLUTIONS:
        return
    
    if df.shape[0] > MAX_SOLUTIONS:
        df = df.sample(MAX_SOLUTIONS, ignore_index=True)
    
    print(f'{pid}','-'*50)
    print(f' sampled {df.shape[0]} code snippets')
    
    df['src'] = df.apply(lambda row: codenet_reader.read_solution_file(pid, row['submission_id']), axis=1)
    df['lbl'] = df.apply(lambda row: label(pid, row), axis=1)
    
    new_srcs = df['src']
    new_lbls = df['lbl']
    
    srcs.extend(new_srcs.to_list())
    lbls.extend(new_lbls.to_list())
    
    return new_srcs, new_lbls


def test():
    return process_pid('p03200', [], [])
    #return process_pid('p01701', [], [])

# %%
test()
# Out:
# p03200 --------------------------------------------------
#  sampled 250 code snippets
# (0      def main():\n    S = input()\n    w = 0\n    r...
#  1      S = input()\n\nans = 0\ncnt = 0\nfor i in rang...
#  2      s = input()\nn = len(s)\n\nb = 0\nb_count = 0\...
#  3      import sys\n\n\ndef main():\n    s = sys.stdin...
#  4      S=input()\nS=S[::-1]\nans=0\ncount=0\nfor i in...
#                               ...
#  245    import sys\n# input = sys.stdin.readline\n\nde...
#  246    A = list(input())\n\ncount = 0\nans = 0\nfor a...
#  247    #template\ndef inputlist(): return [int(j) for...
#  248    S = str(input())\ncounter = 0\nans = 0\nfor i,...
#  249    def resolve():\n    s = str(input())\n    ans ...
#  Name: src, Length: 250, dtype: object,
#  0      p03200-1
#  1      p03200-1
#  2      p03200-1
#  3      p03200-1
#  4      p03200-1
#           ...
#  245    p03200-1
#  246    p03200-1
#  247    p03200-1
#  248    p03200-1
#  249    p03200-1
#  Name: lbl, Length: 250, dtype: object)

# %%
# Reading data

SAMPLE_SIZE = 500

_pids = os.listdir(codenet_reader.DATA_PATH)
_pids = random.sample(_pids, k=min(SAMPLE_SIZE, len(_pids)))

srcs = []
lbls = []

print('Starting...')
print(f'Processing {len(_pids)} problems.')

for _pid in _pids:
    process_pid(_pid, srcs, lbls)

n_srcs = len(srcs)
n_lbls = len(lbls)
assert n_srcs == n_lbls

accepted_count = sum(1 for lbl in lbls if lbl[-1]=='1')
rejected_count = n_srcs - accepted_count

print('Data gathered...')
print(f'{len(srcs)} code snippets:')
print(f' {accepted_count} accepted')
print(f' {rejected_count} rejected')

output_ls = list(zip(srcs, lbls))
output_df = pd.DataFrame(output_ls, columns=['source', 'label'])

print('DONE')
# Out:
# Starting...
# Processing 500 problems.
# p03422 --------------------------------------------------
#  sampled 22 code snippets
# p02367 --------------------------------------------------
#  sampled 14 code snippets
# p00094 --------------------------------------------------
#  sampled 158 code snippets
# p03789 --------------------------------------------------
#  sampled 7 code snippets
# p02783 --------------------------------------------------
#  sampled 250 code snippets
# p02417 --------------------------------------------------
#  sampled 250 code snippets
# p02861 --------------------------------------------------
#  sampled 250 code snippets
# p02866 --------------------------------------------------
#  sampled 250 code snippets
# p02680 --------------------------------------------------
#  sampled 250 code snippets
# p00027 --------------------------------------------------
#  sampled 10 code snippets
# p02451 --------------------------------------------------
#  sampled 11 code snippets
# p00412 --------------------------------------------------
#  sampled 5 code snippets
# p02389 --------------------------------------------------
#  sampled 250 code snippets
# p03528 --------------------------------------------------
#  sampled 14 code snippets
# p03384 --------------------------------------------------
#  sampled 9 code snippets
# p02917 --------------------------------------------------
#  sampled 250 code snippets
# p02823 --------------------------------------------------
#  sampled 250 code snippets
# p02348 --------------------------------------------------
#  sampled 8 code snippets
# p02833 --------------------------------------------------
#  sampled 250 code snippets
# p03733 --------------------------------------------------
#  sampled 250 code snippets
# p03829 --------------------------------------------------
#  sampled 250 code snippets
# p03250 --------------------------------------------------
#  sampled 250 code snippets
# p03589 --------------------------------------------------
#  sampled 40 code snippets
# p02793 --------------------------------------------------
#  sampled 250 code snippets
# p03687 --------------------------------------------------
#  sampled 250 code snippets
# p03998 --------------------------------------------------
#  sampled 250 code snippets
# p02768 --------------------------------------------------
#  sampled 250 code snippets
# p03073 --------------------------------------------------
#  sampled 250 code snippets
# p02423 --------------------------------------------------
#  sampled 7 code snippets
# p00722 --------------------------------------------------
#  sampled 8 code snippets
# p03012 --------------------------------------------------
#  sampled 250 code snippets
# p02266 --------------------------------------------------
#  sampled 106 code snippets
# p02260 --------------------------------------------------
#  sampled 235 code snippets
# p03472 --------------------------------------------------
#  sampled 250 code snippets
# p03408 --------------------------------------------------
#  sampled 250 code snippets
# p03394 --------------------------------------------------
#  sampled 167 code snippets
# p03673 --------------------------------------------------
#  sampled 250 code snippets
# p03937 --------------------------------------------------
#  sampled 250 code snippets
# p02811 --------------------------------------------------
#  sampled 250 code snippets
# p02732 --------------------------------------------------
#  sampled 250 code snippets
# p00273 --------------------------------------------------
#  sampled 6 code snippets
# p02352 --------------------------------------------------
#  sampled 8 code snippets
# p00400 --------------------------------------------------
#  sampled 30 code snippets
# p03764 --------------------------------------------------
#  sampled 22 code snippets
# p03920 --------------------------------------------------
#  sampled 29 code snippets
# p00050 --------------------------------------------------
#  sampled 49 code snippets
# p03133 --------------------------------------------------
#  sampled 14 code snippets
# p02948 --------------------------------------------------
#  sampled 250 code snippets
# p00355 --------------------------------------------------
#  sampled 5 code snippets
# p02441 --------------------------------------------------
#  sampled 20 code snippets
# p03607 --------------------------------------------------
#  sampled 250 code snippets
# p00062 --------------------------------------------------
#  sampled 6 code snippets
# p04005 --------------------------------------------------
#  sampled 250 code snippets
# p02918 --------------------------------------------------
#  sampled 250 code snippets
# p03702 --------------------------------------------------
#  sampled 19 code snippets
# p03952 --------------------------------------------------
#  sampled 201 code snippets
# p03164 --------------------------------------------------
#  sampled 250 code snippets
# p02586 --------------------------------------------------
#  sampled 250 code snippets
# p02464 --------------------------------------------------
#  sampled 9 code snippets
# p03338 --------------------------------------------------
#  sampled 250 code snippets
# p03276 --------------------------------------------------
#  sampled 97 code snippets
# p00426 --------------------------------------------------
#  sampled 13 code snippets
# p03006 --------------------------------------------------
#  sampled 250 code snippets
# p02554 --------------------------------------------------
#  sampled 250 code snippets
# p02587 --------------------------------------------------
#  sampled 118 code snippets
# p02746 --------------------------------------------------
#  sampled 198 code snippets
# p03181 --------------------------------------------------
#  sampled 137 code snippets
# p02700 --------------------------------------------------
#  sampled 250 code snippets
# p03573 --------------------------------------------------
#  sampled 250 code snippets
# p03045 --------------------------------------------------
#  sampled 250 code snippets
# p02674 --------------------------------------------------
#  sampled 26 code snippets
# p02711 --------------------------------------------------
#  sampled 250 code snippets
# p01614 --------------------------------------------------
#  sampled 5 code snippets
# p03479 --------------------------------------------------
#  sampled 250 code snippets
# p02801 --------------------------------------------------
#  sampled 250 code snippets
# p00046 --------------------------------------------------
#  sampled 12 code snippets
# p03495 --------------------------------------------------
#  sampled 250 code snippets
# p03216 --------------------------------------------------
#  sampled 82 code snippets
# p02405 --------------------------------------------------
#  sampled 250 code snippets
# p02726 --------------------------------------------------
#  sampled 250 code snippets
# p02299 --------------------------------------------------
#  sampled 8 code snippets
# p03400 --------------------------------------------------
#  sampled 250 code snippets
# p03090 --------------------------------------------------
#  sampled 239 code snippets
# p03112 --------------------------------------------------
#  sampled 250 code snippets
# p02708 --------------------------------------------------
#  sampled 250 code snippets
# p02734 --------------------------------------------------
#  sampled 250 code snippets
# p03253 --------------------------------------------------
#  sampled 250 code snippets
# p00340 --------------------------------------------------
#  sampled 151 code snippets
# p02850 --------------------------------------------------
#  sampled 250 code snippets
# p02757 --------------------------------------------------
#  sampled 250 code snippets
# p03162 --------------------------------------------------
#  sampled 250 code snippets
# p03909 --------------------------------------------------
#  sampled 191 code snippets
# p03383 --------------------------------------------------
#  sampled 18 code snippets
# p03543 --------------------------------------------------
#  sampled 250 code snippets
# p00399 --------------------------------------------------
#  sampled 51 code snippets
# p03308 --------------------------------------------------
#  sampled 250 code snippets
# p00433 --------------------------------------------------
#  sampled 8 code snippets
# p00175 --------------------------------------------------
#  sampled 5 code snippets
# p03416 --------------------------------------------------
#  sampled 250 code snippets
# p03853 --------------------------------------------------
#  sampled 250 code snippets
# p02996 --------------------------------------------------
#  sampled 250 code snippets
# p00032 --------------------------------------------------
#  sampled 8 code snippets
# p03910 --------------------------------------------------
#  sampled 250 code snippets
# p02703 --------------------------------------------------
#  sampled 250 code snippets
# p02308 --------------------------------------------------
#  sampled 5 code snippets
# p04049 --------------------------------------------------
#  sampled 37 code snippets
# p02562 --------------------------------------------------
#  sampled 76 code snippets
# p02761 --------------------------------------------------
#  sampled 250 code snippets
# p02681 --------------------------------------------------
#  sampled 250 code snippets
# p03199 --------------------------------------------------
#  sampled 10 code snippets
# p02777 --------------------------------------------------
#  sampled 250 code snippets
# p03634 --------------------------------------------------
#  sampled 250 code snippets
# p02212 --------------------------------------------------
#  sampled 26 code snippets
# p03629 --------------------------------------------------
#  sampled 41 code snippets
# p03997 --------------------------------------------------
#  sampled 250 code snippets
# p03987 --------------------------------------------------
#  sampled 97 code snippets
# p03251 --------------------------------------------------
#  sampled 250 code snippets
# p02631 --------------------------------------------------
#  sampled 250 code snippets
# p02991 --------------------------------------------------
#  sampled 250 code snippets
# p03862 --------------------------------------------------
#  sampled 250 code snippets
# p02276 --------------------------------------------------
#  sampled 94 code snippets
# p02971 --------------------------------------------------
#  sampled 250 code snippets
# p03042 --------------------------------------------------
#  sampled 250 code snippets
# p03689 --------------------------------------------------
#  sampled 74 code snippets
# p03362 --------------------------------------------------
#  sampled 250 code snippets
# p03379 --------------------------------------------------
#  sampled 250 code snippets
# p00753 --------------------------------------------------
#  sampled 13 code snippets
# p03005 --------------------------------------------------
#  sampled 250 code snippets
# p03672 --------------------------------------------------
#  sampled 250 code snippets
# p02559 --------------------------------------------------
#  sampled 250 code snippets
# p03056 --------------------------------------------------
#  sampled 9 code snippets
# p02589 --------------------------------------------------
#  sampled 239 code snippets
# p00803 --------------------------------------------------
#  sampled 5 code snippets
# p03025 --------------------------------------------------
#  sampled 30 code snippets
# p03828 --------------------------------------------------
#  sampled 250 code snippets
# p02692 --------------------------------------------------
#  sampled 250 code snippets
# p03013 --------------------------------------------------
#  sampled 250 code snippets
# p03034 --------------------------------------------------
#  sampled 82 code snippets
# p03163 --------------------------------------------------
#  sampled 250 code snippets
# p03665 --------------------------------------------------
#  sampled 250 code snippets
# p00026 --------------------------------------------------
#  sampled 5 code snippets
# p03075 --------------------------------------------------
#  sampled 250 code snippets
# p02733 --------------------------------------------------
#  sampled 250 code snippets
# p03385 --------------------------------------------------
#  sampled 250 code snippets
# p02553 --------------------------------------------------
#  sampled 250 code snippets
# p00423 --------------------------------------------------
#  sampled 5 code snippets
# p02959 --------------------------------------------------
#  sampled 250 code snippets
# p00029 --------------------------------------------------
#  sampled 52 code snippets
# p03019 --------------------------------------------------
#  sampled 26 code snippets
# p02397 --------------------------------------------------
#  sampled 250 code snippets
# p03699 --------------------------------------------------
#  sampled 250 code snippets
# p02770 --------------------------------------------------
#  sampled 214 code snippets
# p03893 --------------------------------------------------
#  sampled 6 code snippets
# p02776 --------------------------------------------------
#  sampled 69 code snippets
# p03813 --------------------------------------------------
#  sampled 250 code snippets
# p03288 --------------------------------------------------
#  sampled 250 code snippets
# p03544 --------------------------------------------------
#  sampled 250 code snippets
# p02433 --------------------------------------------------
#  sampled 23 code snippets
# p03393 --------------------------------------------------
#  sampled 250 code snippets
# p03725 --------------------------------------------------
#  sampled 131 code snippets
# p00010 --------------------------------------------------
#  sampled 6 code snippets
# p03507 --------------------------------------------------
#  sampled 41 code snippets
# p04028 --------------------------------------------------
#  sampled 19 code snippets
# p02595 --------------------------------------------------
#  sampled 250 code snippets
# p03494 --------------------------------------------------
#  sampled 250 code snippets
# p03508 --------------------------------------------------
#  sampled 20 code snippets
# p02272 --------------------------------------------------
#  sampled 92 code snippets
# p03215 --------------------------------------------------
#  sampled 250 code snippets
# p02624 --------------------------------------------------
#  sampled 250 code snippets
# p01227 --------------------------------------------------
#  sampled 8 code snippets
# p03360 --------------------------------------------------
#  sampled 250 code snippets
# p00353 --------------------------------------------------
#  sampled 20 code snippets
# p03614 --------------------------------------------------
#  sampled 48 code snippets
# p03410 --------------------------------------------------
#  sampled 78 code snippets
# p03504 --------------------------------------------------
#  sampled 250 code snippets
# p03008 --------------------------------------------------
#  sampled 146 code snippets
# p03743 --------------------------------------------------
#  sampled 5 code snippets
# p03380 --------------------------------------------------
#  sampled 250 code snippets
# p03156 --------------------------------------------------
#  sampled 250 code snippets
# p03320 --------------------------------------------------
#  sampled 40 code snippets
# p02750 --------------------------------------------------
#  sampled 250 code snippets
# p03525 --------------------------------------------------
#  sampled 250 code snippets
# p03149 --------------------------------------------------
#  sampled 250 code snippets
# p03318 --------------------------------------------------
#  sampled 129 code snippets
# p03155 --------------------------------------------------
#  sampled 250 code snippets
# p03641 --------------------------------------------------
#  sampled 19 code snippets
# p02445 --------------------------------------------------
#  sampled 16 code snippets
# p03563 --------------------------------------------------
#  sampled 250 code snippets
# p02339 --------------------------------------------------
#  sampled 11 code snippets
# p03246 --------------------------------------------------
#  sampled 250 code snippets
# p02335 --------------------------------------------------
#  sampled 13 code snippets
# p02461 --------------------------------------------------
#  sampled 7 code snippets
# p03182 --------------------------------------------------
#  sampled 43 code snippets
# p01096 --------------------------------------------------
#  sampled 23 code snippets
# p02787 --------------------------------------------------
#  sampled 250 code snippets
# p03791 --------------------------------------------------
#  sampled 32 code snippets
# p03061 --------------------------------------------------
#  sampled 250 code snippets
# p02396 --------------------------------------------------
#  sampled 250 code snippets
# p03018 --------------------------------------------------
#  sampled 250 code snippets
# p02927 --------------------------------------------------
#  sampled 250 code snippets
# p02641 --------------------------------------------------
#  sampled 250 code snippets
# p03172 --------------------------------------------------
#  sampled 201 code snippets
# p03487 --------------------------------------------------
#  sampled 250 code snippets
# p02938 --------------------------------------------------
#  sampled 20 code snippets
# p03274 --------------------------------------------------
#  sampled 250 code snippets
# p02564 --------------------------------------------------
#  sampled 210 code snippets
# p02455 --------------------------------------------------
#  sampled 16 code snippets
# p03685 --------------------------------------------------
#  sampled 78 code snippets
# p02408 --------------------------------------------------
#  sampled 250 code snippets
# p00001 --------------------------------------------------
#  sampled 179 code snippets
# p03346 --------------------------------------------------
#  sampled 250 code snippets
# p02289 --------------------------------------------------
#  sampled 48 code snippets
# p03389 --------------------------------------------------
#  sampled 60 code snippets
# p02576 --------------------------------------------------
#  sampled 250 code snippets
# p02256 --------------------------------------------------
#  sampled 250 code snippets
# p03681 --------------------------------------------------
#  sampled 250 code snippets
# p02645 --------------------------------------------------
#  sampled 250 code snippets
# p03450 --------------------------------------------------
#  sampled 250 code snippets
# p00005 --------------------------------------------------
#  sampled 31 code snippets
# p02843 --------------------------------------------------
#  sampled 250 code snippets
# p03663 --------------------------------------------------
#  sampled 53 code snippets
# p03502 --------------------------------------------------
#  sampled 250 code snippets
# p03463 --------------------------------------------------
#  sampled 250 code snippets
# p02235 --------------------------------------------------
#  sampled 67 code snippets
# p02818 --------------------------------------------------
#  sampled 250 code snippets
# p03524 --------------------------------------------------
#  sampled 250 code snippets
# p02536 --------------------------------------------------
#  sampled 250 code snippets
# p02840 --------------------------------------------------
#  sampled 69 code snippets
# Data gathered...
# 36823 code snippets:
#  26714 accepted
#  10109 rejected
# DONE

# %%
output_df
# Out:
#                                                   source     label
# 0      import sys\nread = sys.stdin.buffer.read\nread...  p03422-1
# 1      import sys\nread = sys.stdin.buffer.read\nread...  p03422-0
# 2      N = int(input())\ng = 0\nfor _ in range(N):\n ...  p03422-1
# 3      N = int(input())\n\ndef grundy(x, k):\n    whi...  p03422-1
# 4      A,I=0,input\nfor i in range(int(I())):\n a,k=m...  p03422-1
# ...                                                  ...       ...
# 36818  from operator import itemgetter\n\n\nn, x, d =...  p02840-1
# 36819  from operator import itemgetter\n\n\nn, x, d =...  p02840-0
# 36820  from operator import itemgetter\n\n\nn, x, d =...  p02840-0
# 36821  from operator import itemgetter\n\n\nn, x, d =...  p02840-0
# 36822  from fractions import gcd\n\n# inputa\nn , x ,...  p02840-1
#
# [36823 rows x 2 columns]

# %%
# Exporting
EXPORTED_FILE_NAME = 'output_single.csv'
output_df.to_csv(EXPORTED_FILE_NAME)
